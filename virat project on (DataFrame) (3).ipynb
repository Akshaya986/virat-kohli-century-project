# %%
# !pip install PANDAS

# %%
import pandas as pd

# %%
data=pd.read_csv(r'C:\Users\Administrator\Desktop\virat (1).csv')

# %%
data
# Out:
#     Score Out/Not Out       Against  Batting Order  Inn.  Strike Rate  \
# 0     116         Out     Australia              6     2          NaN
# 1     103         Out   New Zealand              5     2          NaN
# 2     103         Out       England              5     2          NaN
# 3     107         Out     Australia              5     2          NaN
# 4     119         Out  South Africa              4     1          NaN
# ..    ...         ...           ...            ...   ...          ...
# 66    116         Out     Australia              3     1        96.67
# 67    123         Out     Australia              3     2       129.47
# 68    120         Out   West Indies              3     1        96.00
# 69    114     Not Out   West Indies              3     2       115.15
# 70    122     Not Out    Afganistan              1     1       200.00
#
#                                    Venue         Column1   H/A        Date  \
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#     Score Out/Not Out       Against  Batting Order  Inn.  Strike Rate  \
# 0     116         Out     Australia              6     2          NaN
# 1     103         Out   New Zealand              5     2          NaN
# 2     103         Out       England              5     2          NaN
# 3     107         Out     Australia              5     2          NaN
# 4     119         Out  South Africa              4     1          NaN
# ..    ...         ...           ...            ...   ...          ...
# 66    116         Out     Australia              3     1        96.67
# 67    123         Out     Australia              3     2       129.47
# 68    120         Out   West Indies              3     1        96.00
# 69    114     Not Out   West Indies              3     2       115.15
# 70    122     Not Out    Afganistan              1     1       200.00
#
#                                    Venue         Column1   H/A        Date  \
# ...

# %%
df=df.rename(columns={'Against':'contry'})

# %%
df
# Out:
#     Score Out/Not Out        contry  Batting Order  Inn.  Strike Rate  \
# 0     116         Out     Australia              6     2          NaN
# 1     103         Out   New Zealand              5     2          NaN
# 2     103         Out       England              5     2          NaN
# 3     107         Out     Australia              5     2          NaN
# 4     119         Out  South Africa              4     1          NaN
# ..    ...         ...           ...            ...   ...          ...
# 66    116         Out     Australia              3     1        96.67
# 67    123         Out     Australia              3     2       129.47
# 68    120         Out   West Indies              3     1        96.00
# 69    114     Not Out   West Indies              3     2       115.15
# 70    122     Not Out    Afganistan              1     1       200.00
#
#                                    Venue         Column1   H/A        Date  \
# ...

# %%
df=df.rename(columns={'Column1':'location'})

# %%
df
# Out:
#     Score Out/Not Out        contry  Batting Order  Inn.  Strike Rate  \
# 0     116         Out     Australia              6     2          NaN
# 1     103         Out   New Zealand              5     2          NaN
# 2     103         Out       England              5     2          NaN
# 3     107         Out     Australia              5     2          NaN
# 4     119         Out  South Africa              4     1          NaN
# ..    ...         ...           ...            ...   ...          ...
# 66    116         Out     Australia              3     1        96.67
# 67    123         Out     Australia              3     2       129.47
# 68    120         Out   West Indies              3     1        96.00
# 69    114     Not Out   West Indies              3     2       115.15
# 70    122     Not Out    Afganistan              1     1       200.00
#
#                                    Venue        location   H/A        Date  \
# ...

# %%
df.shape
# Out:
# (71, 14)

# %%
df.columns
# Out:
# Index(['Score', 'Out/Not Out', 'contry', 'Batting Order', 'Inn.',
#        'Strike Rate', 'Venue', 'location', 'H/A', 'Date', 'Result', 'Format',
#        'Man of the Match', 'Captain'],
#       dtype='object')

# %%
df.head(5)
# Out:
#    Score Out/Not Out        contry  Batting Order  Inn.  Strike Rate  \
# 0    116         Out     Australia              6     2          NaN
# 1    103         Out   New Zealand              5     2          NaN
# 2    103         Out       England              5     2          NaN
# 3    107         Out     Australia              5     2          NaN
# 4    119         Out  South Africa              4     1          NaN
#
#                                   Venue       location   H/A        Date  \
# 0                         Adelaide Oval       Adelaide  Away  24-01-2012
# 1                M. Chinnaswamy Stadium      Bangalore  Home  31-08-2012
# 2  Vidarbha Cricket Association Stadium         Nagpur  Home  13-12-2012
# 3             M. A. Chidambaram Stadium        Chennai  Home  22-02-2013
# 4                     Wanderers Stadium   Johannesburg  Away  18-12-2013
#
#   Result Format Man of the Match Captain
# 0   Lost   Test               No      No
# ...

# %%
df.tail(6)
# Out:
#     Score Out/Not Out       contry  Batting Order  Inn.  Strike Rate  \
# 65    104         Out    Australia              3     2        92.85
# 66    116         Out    Australia              3     1        96.67
# 67    123         Out    Australia              3     2       129.47
# 68    120         Out  West Indies              3     1        96.00
# 69    114     Not Out  West Indies              3     2       115.15
# 70    122     Not Out   Afganistan              1     1       200.00
#
#                                    Venue        location   H/A        Date  \
# 65                         Adelaide Oval        Adelaide  Away  15-01-2019
# 66  Vidarbha Cricket Association Stadium          Nagpur  Home  05-03-2019
# 67            JSCA International Stadium          Ranchi  Home  08-03-2019
# 68                     Queen's Park Oval   Port of Spain  Away  11-08-2019
# 69                     Queen's Park Oval   Port of Spain  Away  14-08-2019
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Score             71 non-null     int64
#  1   Out/Not Out       71 non-null     object
#  2   contry            71 non-null     object
#  3   Batting Order     71 non-null     int64
#  4   Inn.              71 non-null     int64
#  5   Strike Rate       44 non-null     float64
#  6   Venue             71 non-null     object
#  7   location          71 non-null     object
#  8   H/A               71 non-null     object
#  9   Date              71 non-null     object
#  10  Result            71 non-null     object
#  11  Format            71 non-null     object
#  12  Man of the Match  71 non-null     object
#  13  Captain           71 non-null     object
# dtypes: float64(1), int64(3), object(10)
# memory usage: 7.9+ KB

# %%
df.describe()
# Out:
#             Score  Batting Order       Inn.  Strike Rate
# count   71.000000      71.000000  71.000000    44.000000
# mean   132.140845       3.521127   1.732394   114.019545
# std     35.911119       0.714326   0.675230    25.257567
# min    100.000000       1.000000   1.000000    84.900000
# 25%    107.000000       3.000000   1.000000    96.632500
# 50%    119.000000       3.000000   2.000000   108.935000
# 75%    139.500000       4.000000   2.000000   120.787500
# max    254.000000       6.000000   4.000000   200.000000

# %%
df
# Out:
#     Score Out/Not Out        contry  Batting Order  Inn.  Strike Rate  \
# 0     116         Out     Australia              6     2          NaN
# 1     103         Out   New Zealand              5     2          NaN
# 2     103         Out       England              5     2          NaN
# 3     107         Out     Australia              5     2          NaN
# 4     119         Out  South Africa              4     1          NaN
# ..    ...         ...           ...            ...   ...          ...
# 66    116         Out     Australia              3     1        96.67
# 67    123         Out     Australia              3     2       129.47
# 68    120         Out   West Indies              3     1        96.00
# 69    114     Not Out   West Indies              3     2       115.15
# 70    122     Not Out    Afganistan              1     1       200.00
#
#                                    Venue        location   H/A        Date  \
# ...

# %%
df[["Score","location"]]
# Out:
#     Score        location
# 0     116        Adelaide
# 1     103       Bangalore
# 2     103          Nagpur
# 3     107         Chennai
# 4     119    Johannesburg
# ..    ...             ...
# 66    116          Nagpur
# 67    123          Ranchi
# 68    120   Port of Spain
# 69    114   Port of Spain
# 70    122           Dubai
#
# [71 rows x 2 columns]

# %%
df[["Score","Man of the Match"]]
# Out:
#     Score Man of the Match
# 0     116               No
# 1     103              Yes
# 2     103               No
# 3     107               No
# 4     119               No
# ..    ...              ...
# 66    116              Yes
# 67    123               No
# 68    120              Yes
# 69    114              Yes
# 70    122              Yes
#
# [71 rows x 2 columns]

# %%
df
# Out:
#     Score Out/Not Out        contry  Batting Order  Inn.  Strike Rate  \
# 0     116         Out     Australia              6     2          NaN
# 1     103         Out   New Zealand              5     2          NaN
# 2     103         Out       England              5     2          NaN
# 3     107         Out     Australia              5     2          NaN
# 4     119         Out  South Africa              4     1          NaN
# ..    ...         ...           ...            ...   ...          ...
# 66    116         Out     Australia              3     1        96.67
# 67    123         Out     Australia              3     2       129.47
# 68    120         Out   West Indies              3     1        96.00
# 69    114     Not Out   West Indies              3     2       115.15
# 70    122     Not Out    Afganistan              1     1       200.00
#
#                                    Venue        location   H/A        Date  \
# ...

# %%
df.count()
# Out:
# Score               71
# Out/Not Out         71
# contry              71
# Batting Order       71
# Inn.                71
# Strike Rate         44
# Venue               71
# location            71
# H/A                 71
# Date                71
# Result              71
# Format              71
# Man of the Match    71
# Captain             71
# dtype: int64

# %%
df["Strike Rate"].fillna(99.66,inplace=True)

# %%
df
# Out:
#     Score Out/Not Out        contry  Batting Order  Inn.  Strike Rate  \
# 0     116         Out     Australia              6     2        99.66
# 1     103         Out   New Zealand              5     2        99.66
# 2     103         Out       England              5     2        99.66
# 3     107         Out     Australia              5     2        99.66
# 4     119         Out  South Africa              4     1        99.66
# ..    ...         ...           ...            ...   ...          ...
# 66    116         Out     Australia              3     1        96.67
# 67    123         Out     Australia              3     2       129.47
# 68    120         Out   West Indies              3     1        96.00
# 69    114     Not Out   West Indies              3     2       115.15
# 70    122     Not Out    Afganistan              1     1       200.00
#
#                                    Venue        location   H/A        Date  \
# ...

# %%
df=df.rename(columns={'contry':'country'})

# %%
df[["Result","country"]]
# Out:
#    Result       country
# 0    Lost     Australia
# 1     Won   New Zealand
# 2   Drawn       England
# 3     Won     Australia
# 4   Drawn  South Africa
# ..    ...           ...
# 66    Won     Australia
# 67   Lost     Australia
# 68    Won   West Indies
# 69    Won   West Indies
# 70    Won    Afganistan
#
# [71 rows x 2 columns]

# %%
df[0:9]
# Out:
#    Score Out/Not Out       country  Batting Order  Inn.  Strike Rate  \
# 0    116         Out     Australia              6     2        99.66
# 1    103         Out   New Zealand              5     2        99.66
# 2    103         Out       England              5     2        99.66
# 3    107         Out     Australia              5     2        99.66
# 4    119         Out  South Africa              4     1        99.66
# 5    105     Not Out   New Zealand              4     4        99.66
# 6    115         Out     Australia              4     2        99.66
# 7    141         Out     Australia              4     4        99.66
# 8    169         Out     Australia              4     2        99.66
#
#                                   Venue       location   H/A        Date  \
# 0                         Adelaide Oval       Adelaide  Away  24-01-2012
# 1                M. Chinnaswamy Stadium      Bangalore  Home  31-08-2012
# ...

# %%
df[0:10:2]
# Out:
#    Score Out/Not Out       country  Batting Order  Inn.  Strike Rate  \
# 0    116         Out     Australia              6     2        99.66
# 2    103         Out       England              5     2        99.66
# 4    119         Out  South Africa              4     1        99.66
# 6    115         Out     Australia              4     2        99.66
# 8    169         Out     Australia              4     2        99.66
#
#                                   Venue       location   H/A        Date  \
# 0                         Adelaide Oval       Adelaide  Away  24-01-2012
# 2  Vidarbha Cricket Association Stadium         Nagpur  Home  13-12-2012
# 4                     Wanderers Stadium   Johannesburg  Away  18-12-2013
# 6                         Adelaide Oval       Adelaide  Away  09-12-2014
# 8              Melbourne Cricket Ground      Melbourne  Away  26-12-2014
#
#   Result Format Man of the Match Captain
# 0   Lost   Test               No      No
# ...

# %%
df.loc[df["country"].str.contains("A")]
# Out:
#     Score Out/Not Out       country  Batting Order  Inn.  Strike Rate  \
# 0     116         Out     Australia              6     2        99.66
# 3     107         Out     Australia              5     2        99.66
# 4     119         Out  South Africa              4     1        99.66
# 6     115         Out     Australia              4     2        99.66
# 7     141         Out     Australia              4     4        99.66
# 8     169         Out     Australia              4     2        99.66
# 9     147         Out     Australia              4     2        99.66
# 20    153         Out  South Africa              4     2        99.66
# 24    123         Out     Australia              4     2        99.66
# 25    254     Not Out  South Africa              4     1        99.66
# 29    118         Out     Australia              3     2        97.52
# 42    100     Not Out     Australia              3     2       192.30
# ...

# %%
df["Score"].sum()
# Out:
# 9382

# %%
df["Score"].mean()
# Out:
# 132.14084507042253

# %%
df["Score"].median()
# Out:
# 119.0

# %%
df["Strike Rate"]. agg({'sum','min','max','median'})
# Out:
# max        200.00
# median      99.66
# min         84.90
# sum       7707.68
# Name: Strike Rate, dtype: float64

# %%
df["Strike Rate"].max()
# Out:
# 200.0

# %%
df.groupby("country")["Score"].sum()
# Out:
# country
# Afganistan       122
# Australia       1817
# Bangladesh       678
# England         1098
# New Zealand     1035
# Pakistan         290
# South Africa    1065
# Sri Lanka       1728
# West Indies     1434
# Zimbabwe         115
# Name: Score, dtype: int64

# %%
df
# Out:
#     Score Out/Not Out       country  Batting Order  Inn.  Strike Rate  \
# 0     116         Out     Australia              6     2        99.66
# 1     103         Out   New Zealand              5     2        99.66
# 2     103         Out       England              5     2        99.66
# 3     107         Out     Australia              5     2        99.66
# 4     119         Out  South Africa              4     1        99.66
# ..    ...         ...           ...            ...   ...          ...
# 66    116         Out     Australia              3     1        96.67
# 67    123         Out     Australia              3     2       129.47
# 68    120         Out   West Indies              3     1        96.00
# 69    114     Not Out   West Indies              3     2       115.15
# 70    122     Not Out    Afganistan              1     1       200.00
#
#                                    Venue        location   H/A        Date  \
# ...

# %%
df.groupby(["Batting Order","Inn."])["Strike Rate"].agg({'count','sum','max','min','median','mean'})
# Out:
#                        max  median        mean  count     min      sum
# Batting Order Inn.
# 1             1     200.00  200.00  200.000000      1  200.00   200.00
# 3             1     136.45  100.00  103.824667     15   84.90  1557.37
#               2     192.30  111.47  116.940476     21   89.91  2455.75
# 4             1     120.48   99.66  103.281000     10   99.66  1032.81
#               2     154.65   99.66  104.320667     15   93.85  1564.81
#               3      99.66   99.66   99.660000      3   99.66   298.98
#               4      99.66   99.66   99.660000      2   99.66   199.32
# 5             2      99.66   99.66   99.660000      3   99.66   298.98
# 6             2      99.66   99.66   99.660000      1   99.66    99.66

# %%
df[0:12]
# Out:
#     Score Out/Not Out       country  Batting Order  Inn.  Strike Rate  \
# 0     116         Out     Australia              6     2        99.66
# 1     103         Out   New Zealand              5     2        99.66
# 2     103         Out       England              5     2        99.66
# 3     107         Out     Australia              5     2        99.66
# 4     119         Out  South Africa              4     1        99.66
# 5     105     Not Out   New Zealand              4     4        99.66
# 6     115         Out     Australia              4     2        99.66
# 7     141         Out     Australia              4     4        99.66
# 8     169         Out     Australia              4     2        99.66
# 9     147         Out     Australia              4     2        99.66
# 10    103         Out     Sri Lanka              4     2        99.66
# 11    200         Out   West Indies              4     1        99.66
#
# ...

# %%
df.loc[df["country"].str.startswith("s")]
# Out:
# Empty DataFrame
# Columns: [Score, Out/Not Out, country, Batting Order, Inn., Strike Rate, Venue, location, H/A, Date, Result, Format, Man of the Match, Captain]
# Index: []

# %%
df.loc[df["country"].str.endswith("s")]
# Out:
#     Score Out/Not Out      country  Batting Order  Inn.  Strike Rate  \
# 11    200         Out  West Indies              4     1        99.66
# 23    139         Out  West Indies              4     1        99.66
# 34    117         Out  West Indies              4     2        95.12
# 40    102         Out  West Indies              3     1       122.89
# 46    127         Out  West Indies              3     1       111.40
# 54    111     Not Out  West Indies              3     2        96.52
# 62    140         Out  West Indies              3     2       130.84
# 63    157     Not Out  West Indies              3     1       121.71
# 64    107         Out  West Indies              3     2        89.91
# 68    120         Out  West Indies              3     1        96.00
# 69    114     Not Out  West Indies              3     2       115.15
#
#                                       Venue        location   H/A        Date  \
# ...

# %%
for i in df.iterrows():
    print(i)
# Out:
# (0, Score                         116
# Out/Not Out                   Out
# country                 Australia
# Batting Order                   6
# Inn.                            2
# Strike Rate                 99.66
# Venue               Adelaide Oval
# location                 Adelaide
# H/A                          Away
# Date                   24-01-2012
# Result                       Lost
# Format                       Test
# Man of the Match               No
# Captain                        No
# Name: 0, dtype: object)
# (1, Score                                  103
# Out/Not Out                            Out
# country                        New Zealand
# Batting Order                            5
# Inn.                                     2
# Strike Rate                          99.66
# Venue               M. Chinnaswamy Stadium
# location                         Bangalore
# H/A                                   Home
# Date                            31-08-2012
# ...

# %%
df[0:4]
# Out:
#    Score Out/Not Out      country  Batting Order  Inn.  Strike Rate  \
# 0    116         Out    Australia              6     2        99.66
# 1    103         Out  New Zealand              5     2        99.66
# 2    103         Out      England              5     2        99.66
# 3    107         Out    Australia              5     2        99.66
#
#                                   Venue    location   H/A        Date Result  \
# 0                         Adelaide Oval    Adelaide  Away  24-01-2012   Lost
# 1                M. Chinnaswamy Stadium   Bangalore  Home  31-08-2012    Won
# 2  Vidarbha Cricket Association Stadium      Nagpur  Home  13-12-2012  Drawn
# 3             M. A. Chidambaram Stadium     Chennai  Home  22-02-2013    Won
#
#   Format Man of the Match Captain
# 0   Test               No      No
# 1   Test              Yes      No
# 2   Test               No      No
# 3   Test               No      No

# %%
df[["Score","Result"]][0:5]
# Out:
#    Score Result
# 0    116   Lost
# 1    103    Won
# 2    103  Drawn
# 3    107    Won
# 4    119  Drawn

# %%
df.iloc[0:5,[1,8,4]]
# Out:
#   Out/Not Out   H/A  Inn.
# 0         Out  Away     2
# 1         Out  Home     2
# 2         Out  Home     2
# 3         Out  Home     2
# 4         Out  Away     1

# %%
df.sort_values(by="Inn.",ascending=False)
# Out:
#     Score Out/Not Out       country  Batting Order  Inn.  Strike Rate  \
# 5     105     Not Out   New Zealand              4     4        99.66
# 7     141         Out     Australia              4     4        99.66
# 16    103     Not Out     Sri Lanka              4     3        99.66
# 22    103         Out       England              4     3        99.66
# 17    104     Not Out     Sri Lanka              4     3        99.66
# ..    ...         ...           ...            ...   ...          ...
# 25    254     Not Out  South Africa              4     1        99.66
# 38    106         Out     Sri Lanka              3     1        93.80
# 36    108         Out     Sri Lanka              3     1        90.00
# 32    107         Out       England              4     1       115.05
# 70    122     Not Out    Afganistan              1     1       200.00
#
#                                       Venue     location   H/A        Date  \
# ...

# %%
df.sort_values(by="Inn.",ascending=False).tail(8)
# Out:
#     Score Out/Not Out       country  Batting Order  Inn.  Strike Rate  \
# 19    243         Out     Sri Lanka              4     1        99.66
# 23    139         Out   West Indies              4     1        99.66
# 40    102         Out   West Indies              3     1       122.89
# 25    254     Not Out  South Africa              4     1        99.66
# 38    106         Out     Sri Lanka              3     1        93.80
# 36    108         Out     Sri Lanka              3     1        90.00
# 32    107         Out       England              4     1       115.05
# 70    122     Not Out    Afganistan              1     1       200.00
#
#                                       Venue        location   H/A        Date  \
# 19                  Feroz Shah Kotla Ground           Delhi  Home  02-12-2017
# 23   Saurashtra Cricket Association Stadium          Rajkot  Home  04-10-2018
# 40                        Queen's Park Oval   Port of Spain  Away  05-07-2013
# ...

# %%
df[0:18:2][["Score","country","Man of the Match"]]
# Out:
#     Score       country Man of the Match
# 0     116     Australia               No
# 2     103       England               No
# 4     119  South Africa               No
# 6     115     Australia               No
# 8     169     Australia               No
# 10    103     Sri Lanka               No
# 12    211   New Zealand               No
# 14    235       England              Yes
# 16    103     Sri Lanka               No

# %%
df.iloc[0:8,[1,4,12,13]]
# Out:
#   Out/Not Out  Inn. Man of the Match Captain
# 0         Out     2               No      No
# 1         Out     2              Yes      No
# 2         Out     2               No      No
# 3         Out     2               No      No
# 4         Out     1               No      No
# 5     Not Out     4               No      No
# 6         Out     2               No     Yes
# 7         Out     4               No     Yes

# %%
df[["Score","Out/Not Out","Inn."]].sort_values(by="Inn.",ascending=False).head(7)
# Out:
#     Score Out/Not Out  Inn.
# 5     105     Not Out     4
# 7     141         Out     4
# 16    103     Not Out     3
# 22    103         Out     3
# 17    104     Not Out     3
# 0     116         Out     2
# 1     103         Out     2

# %%
df["Score"].sum
# Out:
# <bound method Series.sum of 0     116
# 1     103
# 2     103
# 3     107
# 4     119
#      ...
# 66    116
# 67    123
# 68    120
# 69    114
# 70    122
# Name: Score, Length: 71, dtype: int64>

# %%
df["Score"].mean()
# Out:
# 132.14084507042253

# %%
df["Score"].median()
# Out:
# 119.0

# %%
df["Strike Rate"].agg({"sum","min","max","median","mean"})
# Out:
# max        200.000000
# median      99.660000
# mean       108.558873
# min         84.900000
# sum       7707.680000
# Name: Strike Rate, dtype: float64

# %%
df.groupby(["Strike Rate",])["Score"].agg({"count","sum","max","min","mean","median"})
# Out:
#              max  median        mean  count  min   sum
# Strike Rate
# 84.90        107   107.0  107.000000      1  107   107
# 89.91        107   107.0  107.000000      1  107   107
# 90.00        108   108.0  108.000000      1  108   108
# 92.85        104   104.0  104.000000      1  104   104
# 93.80        106   106.0  106.000000      1  106   106
# 93.85        107   107.0  107.000000      1  107   107
# 94.11        112   112.0  112.000000      1  112   112
# 94.82        110   110.0  110.000000      1  110   110
# 95.12        117   117.0  117.000000      1  117   117
# 96.00        120   120.0  120.000000      1  120   120
# 96.52        111   111.0  111.000000      1  111   111
# 96.67        116   116.0  116.000000      1  116   116
# 96.80        121   121.0  121.000000      1  121   121
# 97.52        118   118.0  118.000000      1  118   118
# 98.57        138   138.0  138.000000      1  138   138
# 99.66        254   139.0  150.555556     27  103  4065
# ...

# %%
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
x=df["country"].head()
y=df["Strike Rate"].head().sort_values(ascending=False)

plt.bar(x,y)
plt.xlabel("country")
plt.ylabel("Strike Rate")
plt.title("country wise strike rate")
plt.show()

# %%
x=df["country"].head()
y=df["Strike Rate"].head().sort_values(ascending=False)

plt.barh(x,y)
plt.xlabel("country")
plt.ylabel("Strike Rate")
plt.title("country wise strike rate")
plt.show()

# %%
x=df["country"].head()
y=df["Strike Rate"].head()

plt.plot(x,y)
plt.xlabel("country")
plt.ylabel("Strike Rate")
plt.title("country wise strike rate")
plt.show()

# %%
x=df["country"].head(3)
y=df["Strike Rate"].head(3)

plt.figure(figsize=(6,8))
plt.pie(y,labels=x,startangle=0,explode=[0.1,0,0,],shadow=False,colors=["green","yellow","blue"])
plt.legend(title="country wise strike rate")
plt.show()

# %%
import seaborn as sns

# %%
x=df["country"].head()
y=df["Score"].head().sort_values(ascending=False)

plt.bar(x,y)
plt.xlabel("country")
plt.ylabel("Strike Rate")
plt.title("country wise strike rate")
plt.show()

# %%
sns.barplot(x="Score",y="country",data=df)
plt.title("total score")
plt.show()

# %%
sns.barplot(x="Strike Rate",y="country",orient="horizontal",data=df)
plt.show()
